# %% [markdown]
# <a href="https://colab.research.google.com/github/ktktmahmut/Melanoma/blob/main/Incept%C4%B1onV3_Epo64.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/gdrive')
# %cd /gdrive
# Out:
# Mounted at /gdrive
# /gdrive

# %%
import sys
import os
from os.path import join
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
 
import tensorflow as tf
# import tensorflow_addons as tf
from tensorflow import keras
from tensorflow.keras import optimizers
from tensorflow.keras.optimizers import schedules
from keras.preprocessing.image import load_img, img_to_array
from keras import models, regularizers, layers, optimizers, losses, metrics
from keras.models import Sequential
from keras.layers import Dense
from keras.utils.np_utils import to_categorical
from tensorflow.keras.applications import InceptionV3

from keras.preprocessing.image import ImageDataGenerator
from keras.preprocessing import image

# %%
PATH = "/gdrive/My Drive/DermMel/"
print(os.listdir(PATH))
# Out:
# ['valid', 'train_sep', 'test', 'best_model.hdf5', 'model.hdf5', 'AlexNetModel.hdf5']

# %%
PATHtrain = PATH + 'train_sep/'
print(len(os.listdir(PATHtrain)), " TRAIN Directories of photos")
Labels = os.listdir(PATHtrain)
sig = 0
for label in sorted(Labels):
    print(label,len(os.listdir(PATHtrain + label +'/')))
    sig = sig + len(os.listdir(PATHtrain + label +'/'))

print("Total TRAIN photos ", sig)
print("_"*50)

PATHvalid = PATH + 'valid/'
print(len(os.listdir(PATHvalid)), " VALID Directories of photos")
Labels = os.listdir(PATHvalid)
sig = 0
for label in sorted(Labels):
    print(label,len(os.listdir(PATHvalid + label +'/')))
    sig = sig + len(os.listdir(PATHvalid + label +'/'))

print("Total Validation photos ", sig)
print("_"*50)

PATHtest = PATH + 'test/'
print(len(os.listdir(PATHtest)), " TEST Directories of photos")
Labels = os.listdir(PATHtest)
sig = 0
for label in sorted(Labels):
    print(label,len(os.listdir(PATHtest + label +'/')))
    sig = sig + len(os.listdir(PATHtest + label +'/'))

print("Total Testing photos ", sig)
print("_"*50)
# Out:
# 2  TRAIN Directories of photos
# Melanoma 5341
# NotMelanoma 5341
# Total TRAIN photos  10682
# __________________________________________________
# 2  VALID Directories of photos
# Melanoma 1781
# NotMelanoma 1781
# Total Validation photos  3562
# __________________________________________________
# 2  TEST Directories of photos
# Melanoma 1781
# NotMelanoma 1780
# Total Testing photos  3561
# __________________________________________________

# %%
TestNum = 77
diag = 'Melanoma'

image_dir = PATHtrain +'/'+diag+'/'
img_name = os.listdir(image_dir)[TestNum]
img_path = image_dir+str(img_name)
img = image.load_img(img_path, target_size=(224, 224))
imgplot = plt.imshow(img)
print("TRAIN ",diag," photo number ", TestNum)
plt.show()

image_dir = PATHvalid +'/'+diag+'/'
img_name = os.listdir(image_dir)[TestNum]
img_path = image_dir+str(img_name)
img = image.load_img(img_path, target_size=(224, 224))
imgplot = plt.imshow(img)
print("VALID ",diag," photo number ", TestNum)
plt.show()

image_dir = PATHtest +'/'+diag+'/'
img_name = os.listdir(image_dir)[TestNum]
img_path = image_dir+str(img_name)
img = image.load_img(img_path, target_size=(224, 224))
imgplot = plt.imshow(img)
print("TEST ",diag," photo number ", TestNum)
plt.show()
# Out:
# TRAIN  Melanoma  photo number  77
# VALID  Melanoma  photo number  77
# TEST  Melanoma  photo number  77

# %%
from tensorflow.keras.optimizers import schedules

# %%
import keras
from keras.callbacks import EarlyStopping,ModelCheckpoint,LearningRateScheduler
from keras.layers import Conv2D,BatchNormalization,MaxPool2D,Flatten,Dense
from keras.regularizers import l2
from tensorflow.keras.optimizers import schedules
from tensorflow import keras
from tensorflow.keras import models
#from tensorflow_addons.optimizers import schedules
EP=90
LR=0.0001
DR=LR/EP
MM=0.8
K=0.2

"lr=0.0001"
"--USING THIS--"
def lr_scheduler(epoch, lr):return lr* float((np.exp(- (epoch*DR))))
    
LRD=LearningRateScheduler(lr_scheduler)

callbacks_list=[LRD]



"--NOT USING THIS--"
lr_schedule = keras.optimizers.schedules.ExponentialDecay(
    initial_learning_rate=0.01,
    decay_steps=1000,
    decay_rate=DR)




"-- KEEP THIS IN MIND--"
#This line below give error because a non sense reason 
#OPT=keras.optimizers.Adam(lr=lr_schedule,decy_rate=DR)

"--CORRECT WAY WITH LEARNING RATE SCHEDULE--"
OPT=keras.optimizers.Adam(learning_rate=LR)


model = keras.Sequential()
model.add(InceptionV3(input_shape=(224, 224, 3), include_top=False, weights='imagenet'))
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.GlobalAveragePooling2D())
model.add(keras.layers.Flatten())
model.add(keras.layers.Dropout(0.5))
model.add(keras.layers.Dense(256, activation='relu',kernel_regularizer=l2(0.05), bias_regularizer=l2(0.05)))
model.add(keras.layers.BatchNormalization())
model.add(keras.layers.Dropout(0.3))
model.add(keras.layers.Dense(2, activation='sigmoid')) 

# monitor
early_stopping_monitor = EarlyStopping(patience=100,monitor='val_accuracy')
model_checkpoint_callback = ModelCheckpoint(filepath='/gdrive/My Drive/chkpoint/',
                                            save_weights_only=True,
                                            monitor='val_accuracy',
                                            mode='auto',
                                            save_best_only=True,
                                            verbose=1)


#categorical_crossentropy
model.compile(loss='categorical_crossentropy', optimizer=OPT, metrics=['accuracy', 'AUC'])
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step
# 87924736/87910968 [==============================] - 1s 0us/step

# %%
print(model.summary())
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  inception_v3 (Functional)   (None, 5, 5, 2048)        21802784
#
#  dropout (Dropout)           (None, 5, 5, 2048)        0
#
#  global_average_pooling2d (G  (None, 2048)             0
#  lobalAveragePooling2D)
#
#  flatten (Flatten)           (None, 2048)              0
#
#  dropout_1 (Dropout)         (None, 2048)              0
#
#  dense (Dense)               (None, 256)               524544
#
#  batch_normalization_94 (Bat  (None, 256)              1024
#  chNormalization)
#
#  dropout_2 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 2)                 514
#
# =================================================================
# Total params: 22,328,866
# Trainable params: 22,293,922
# Non-trainable params: 34,944
# _________________________________________________________________
# None

# %%
train_dir = PATHtrain
validation_dir = PATHvalid
test_dir = PATHtest
target_size=(112, 112)
batch_size=64
#train_datagen = ImageDataGenerator(rescale=1./255)
train_datagen = ImageDataGenerator(rescale=1./255,
                                   rotation_range=45,
                                   width_shift_range=0.2,
                                   height_shift_range=0.2,
                                   shear_range=0.2,
                                   zoom_range=0.2,
                                   
                                   horizontal_flip=True,
                                   vertical_flip=True,
                                   fill_mode='nearest')

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
    train_dir,target_size=target_size,batch_size=batch_size,shuffle=True,seed=42)
validation_generator = test_datagen.flow_from_directory(
    validation_dir,target_size=target_size,batch_size=batch_size,shuffle=True,seed=42)
test_generator = test_datagen.flow_from_directory(
    test_dir,target_size=target_size,batch_size=1)
# Out:
# Found 10682 images belonging to 2 classes.
# Found 3562 images belonging to 2 classes.
# Found 3561 images belonging to 2 classes.

# %%
print(train_generator.class_indices)
print(validation_generator.class_indices)
print(test_generator.class_indices)
# Out:
# {'Melanoma': 0, 'NotMelanoma': 1}
# {'Melanoma': 0, 'NotMelanoma': 1}
# {'Melanoma': 0, 'NotMelanoma': 1}

# %%
history = model.fit(train_generator, epochs=64, 
                    steps_per_epoch=train_generator.n//train_generator.batch_size,
                    validation_data=validation_generator, 
                    validation_steps=validation_generator.n//validation_generator.batch_size,
                    callbacks=[early_stopping_monitor,model_checkpoint_callback, LRD])
# Out:
# Epoch 1/64
# 166/166 [==============================] - ETA: 0s - loss: 18.3906 - accuracy: 0.7251 - auc: 0.7432
# Epoch 1: val_accuracy improved from -inf to 0.73040, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 2647s 15s/step - loss: 18.3906 - accuracy: 0.7251 - auc: 0.7432 - val_loss: 14.5469 - val_accuracy: 0.7304 - val_auc: 0.8118 - lr: 1.0000e-04
# Epoch 2/64
# 166/166 [==============================] - ETA: 0s - loss: 10.6834 - accuracy: 0.8627 - auc: 0.9042
# Epoch 2: val_accuracy improved from 0.73040 to 0.85256, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 174s 1s/step - loss: 10.6834 - accuracy: 0.8627 - auc: 0.9042 - val_loss: 8.0385 - val_accuracy: 0.8526 - val_auc: 0.9380 - lr: 1.0000e-04
# Epoch 3/64
# 166/166 [==============================] - ETA: 0s - loss: 6.1723 - accuracy: 0.8881 - auc: 0.9377
# Epoch 3: val_accuracy did not improve from 0.85256
# 166/166 [==============================] - 163s 979ms/step - loss: 6.1723 - accuracy: 0.8881 - auc: 0.9377 - val_loss: 4.7636 - val_accuracy: 0.8031 - val_auc: 0.8731 - lr: 1.0000e-04
# Epoch 4/64
# 166/166 [==============================] - ETA: 0s - loss: 3.5568 - accuracy: 0.9070 - auc: 0.9558
# Epoch 4: val_accuracy did not improve from 0.85256
# 166/166 [==============================] - 160s 963ms/step - loss: 3.5568 - accuracy: 0.9070 - auc: 0.9558 - val_loss: 2.9128 - val_accuracy: 0.7580 - val_auc: 0.8679 - lr: 9.9999e-05
# Epoch 5/64
# 166/166 [==============================] - ETA: 0s - loss: 2.0734 - accuracy: 0.9183 - auc: 0.9639
# Epoch 5: val_accuracy improved from 0.85256 to 0.90312, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 162s 972ms/step - loss: 2.0734 - accuracy: 0.9183 - auc: 0.9639 - val_loss: 1.6216 - val_accuracy: 0.9031 - val_auc: 0.9595 - lr: 9.9999e-05
# Epoch 6/64
# 166/166 [==============================] - ETA: 0s - loss: 1.2396 - accuracy: 0.9228 - auc: 0.9697
# Epoch 6: val_accuracy did not improve from 0.90312
# 166/166 [==============================] - 159s 958ms/step - loss: 1.2396 - accuracy: 0.9228 - auc: 0.9697 - val_loss: 1.1643 - val_accuracy: 0.8148 - val_auc: 0.8899 - lr: 9.9998e-05
# Epoch 7/64
# 166/166 [==============================] - ETA: 0s - loss: 0.7639 - accuracy: 0.9299 - auc: 0.9749
# Epoch 7: val_accuracy did not improve from 0.90312
# 166/166 [==============================] - 162s 973ms/step - loss: 0.7639 - accuracy: 0.9299 - auc: 0.9749 - val_loss: 0.7320 - val_accuracy: 0.8736 - val_auc: 0.9449 - lr: 9.9998e-05
# Epoch 8/64
# 166/166 [==============================] - ETA: 0s - loss: 0.4926 - accuracy: 0.9371 - auc: 0.9802
# Epoch 8: val_accuracy did not improve from 0.90312
# 166/166 [==============================] - 161s 970ms/step - loss: 0.4926 - accuracy: 0.9371 - auc: 0.9802 - val_loss: 0.5812 - val_accuracy: 0.8523 - val_auc: 0.9318 - lr: 9.9997e-05
# Epoch 9/64
# 166/166 [==============================] - ETA: 0s - loss: 0.3376 - accuracy: 0.9421 - auc: 0.9843
# Epoch 9: val_accuracy did not improve from 0.90312
# 166/166 [==============================] - 160s 963ms/step - loss: 0.3376 - accuracy: 0.9421 - auc: 0.9843 - val_loss: 0.4204 - val_accuracy: 0.8844 - val_auc: 0.9518 - lr: 9.9996e-05
# Epoch 10/64
# 166/166 [==============================] - ETA: 0s - loss: 0.2591 - accuracy: 0.9415 - auc: 0.9844
# Epoch 10: val_accuracy improved from 0.90312 to 0.93125, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 162s 977ms/step - loss: 0.2591 - accuracy: 0.9415 - auc: 0.9844 - val_loss: 0.2654 - val_accuracy: 0.9312 - val_auc: 0.9774 - lr: 9.9995e-05
# Epoch 11/64
# 166/166 [==============================] - ETA: 0s - loss: 0.2071 - accuracy: 0.9462 - auc: 0.9870
# Epoch 11: val_accuracy improved from 0.93125 to 0.93636, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 164s 986ms/step - loss: 0.2071 - accuracy: 0.9462 - auc: 0.9870 - val_loss: 0.2178 - val_accuracy: 0.9364 - val_auc: 0.9829 - lr: 9.9994e-05
# Epoch 12/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1759 - accuracy: 0.9483 - auc: 0.9887
# Epoch 12: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 163s 984ms/step - loss: 0.1759 - accuracy: 0.9483 - auc: 0.9887 - val_loss: 0.3511 - val_accuracy: 0.8733 - val_auc: 0.9469 - lr: 9.9993e-05
# Epoch 13/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1528 - accuracy: 0.9531 - auc: 0.9897
# Epoch 13: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 167s 1s/step - loss: 0.1528 - accuracy: 0.9531 - auc: 0.9897 - val_loss: 0.2281 - val_accuracy: 0.9170 - val_auc: 0.9739 - lr: 9.9991e-05
# Epoch 14/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1413 - accuracy: 0.9542 - auc: 0.9902
# Epoch 14: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 163s 979ms/step - loss: 0.1413 - accuracy: 0.9542 - auc: 0.9902 - val_loss: 0.3385 - val_accuracy: 0.8716 - val_auc: 0.9424 - lr: 9.9990e-05
# Epoch 15/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1279 - accuracy: 0.9571 - auc: 0.9921
# Epoch 15: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 160s 966ms/step - loss: 0.1279 - accuracy: 0.9571 - auc: 0.9921 - val_loss: 0.2810 - val_accuracy: 0.9071 - val_auc: 0.9653 - lr: 9.9988e-05
# Epoch 16/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1252 - accuracy: 0.9574 - auc: 0.9924
# Epoch 16: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 160s 962ms/step - loss: 0.1252 - accuracy: 0.9574 - auc: 0.9924 - val_loss: 0.2056 - val_accuracy: 0.9256 - val_auc: 0.9794 - lr: 9.9987e-05
# Epoch 17/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1192 - accuracy: 0.9613 - auc: 0.9927
# Epoch 17: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 163s 979ms/step - loss: 0.1192 - accuracy: 0.9613 - auc: 0.9927 - val_loss: 0.3894 - val_accuracy: 0.8582 - val_auc: 0.9348 - lr: 9.9985e-05
# Epoch 18/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1169 - accuracy: 0.9606 - auc: 0.9933
# Epoch 18: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 162s 977ms/step - loss: 0.1169 - accuracy: 0.9606 - auc: 0.9933 - val_loss: 0.3898 - val_accuracy: 0.8577 - val_auc: 0.9357 - lr: 9.9983e-05
# Epoch 19/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1123 - accuracy: 0.9622 - auc: 0.9936
# Epoch 19: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 163s 979ms/step - loss: 0.1123 - accuracy: 0.9622 - auc: 0.9936 - val_loss: 0.1984 - val_accuracy: 0.9330 - val_auc: 0.9809 - lr: 9.9981e-05
# Epoch 20/64
# 166/166 [==============================] - ETA: 0s - loss: 0.1003 - accuracy: 0.9668 - auc: 0.9951
# Epoch 20: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 160s 961ms/step - loss: 0.1003 - accuracy: 0.9668 - auc: 0.9951 - val_loss: 0.7712 - val_accuracy: 0.7077 - val_auc: 0.8343 - lr: 9.9979e-05
# Epoch 21/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0985 - accuracy: 0.9667 - auc: 0.9951
# Epoch 21: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 158s 954ms/step - loss: 0.0985 - accuracy: 0.9667 - auc: 0.9951 - val_loss: 0.2536 - val_accuracy: 0.9125 - val_auc: 0.9691 - lr: 9.9977e-05
# Epoch 22/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0982 - accuracy: 0.9656 - auc: 0.9951
# Epoch 22: val_accuracy did not improve from 0.93636
# 166/166 [==============================] - 160s 965ms/step - loss: 0.0982 - accuracy: 0.9656 - auc: 0.9951 - val_loss: 0.2769 - val_accuracy: 0.9111 - val_auc: 0.9674 - lr: 9.9974e-05
# Epoch 23/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0909 - accuracy: 0.9699 - auc: 0.9958
# Epoch 23: val_accuracy improved from 0.93636 to 0.93750, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 161s 969ms/step - loss: 0.0909 - accuracy: 0.9699 - auc: 0.9958 - val_loss: 0.1953 - val_accuracy: 0.9375 - val_auc: 0.9821 - lr: 9.9972e-05
# Epoch 24/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0890 - accuracy: 0.9707 - auc: 0.9961
# Epoch 24: val_accuracy did not improve from 0.93750
# 166/166 [==============================] - 162s 972ms/step - loss: 0.0890 - accuracy: 0.9707 - auc: 0.9961 - val_loss: 0.2921 - val_accuracy: 0.8955 - val_auc: 0.9596 - lr: 9.9969e-05
# Epoch 25/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0900 - accuracy: 0.9698 - auc: 0.9960
# Epoch 25: val_accuracy did not improve from 0.93750
# 166/166 [==============================] - 162s 973ms/step - loss: 0.0900 - accuracy: 0.9698 - auc: 0.9960 - val_loss: 0.2310 - val_accuracy: 0.9352 - val_auc: 0.9771 - lr: 9.9967e-05
# Epoch 26/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0879 - accuracy: 0.9727 - auc: 0.9961
# Epoch 26: val_accuracy did not improve from 0.93750
# 166/166 [==============================] - 161s 970ms/step - loss: 0.0879 - accuracy: 0.9727 - auc: 0.9961 - val_loss: 0.5151 - val_accuracy: 0.8355 - val_auc: 0.9159 - lr: 9.9964e-05
# Epoch 27/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0896 - accuracy: 0.9726 - auc: 0.9955
# Epoch 27: val_accuracy improved from 0.93750 to 0.94460, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 174s 1s/step - loss: 0.0896 - accuracy: 0.9726 - auc: 0.9955 - val_loss: 0.1798 - val_accuracy: 0.9446 - val_auc: 0.9846 - lr: 9.9961e-05
# Epoch 28/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0806 - accuracy: 0.9748 - auc: 0.9967
# Epoch 28: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 161s 967ms/step - loss: 0.0806 - accuracy: 0.9748 - auc: 0.9967 - val_loss: 0.3117 - val_accuracy: 0.9077 - val_auc: 0.9575 - lr: 9.9958e-05
# Epoch 29/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0772 - accuracy: 0.9777 - auc: 0.9969
# Epoch 29: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 162s 976ms/step - loss: 0.0772 - accuracy: 0.9777 - auc: 0.9969 - val_loss: 0.5368 - val_accuracy: 0.8438 - val_auc: 0.9192 - lr: 9.9955e-05
# Epoch 30/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0756 - accuracy: 0.9750 - auc: 0.9970
# Epoch 30: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 162s 978ms/step - loss: 0.0756 - accuracy: 0.9750 - auc: 0.9970 - val_loss: 0.3718 - val_accuracy: 0.8830 - val_auc: 0.9409 - lr: 9.9952e-05
# Epoch 31/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0738 - accuracy: 0.9755 - auc: 0.9972
# Epoch 31: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 160s 965ms/step - loss: 0.0738 - accuracy: 0.9755 - auc: 0.9972 - val_loss: 0.2499 - val_accuracy: 0.9307 - val_auc: 0.9723 - lr: 9.9948e-05
# Epoch 32/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0692 - accuracy: 0.9794 - auc: 0.9975
# Epoch 32: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 162s 976ms/step - loss: 0.0692 - accuracy: 0.9794 - auc: 0.9975 - val_loss: 0.1916 - val_accuracy: 0.9401 - val_auc: 0.9820 - lr: 9.9945e-05
# Epoch 33/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0691 - accuracy: 0.9777 - auc: 0.9976
# Epoch 33: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 159s 956ms/step - loss: 0.0691 - accuracy: 0.9777 - auc: 0.9976 - val_loss: 0.3055 - val_accuracy: 0.9190 - val_auc: 0.9645 - lr: 9.9941e-05
# Epoch 34/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0687 - accuracy: 0.9792 - auc: 0.9974
# Epoch 34: val_accuracy did not improve from 0.94460
# 166/166 [==============================] - 159s 956ms/step - loss: 0.0687 - accuracy: 0.9792 - auc: 0.9974 - val_loss: 0.7013 - val_accuracy: 0.8065 - val_auc: 0.8558 - lr: 9.9938e-05
# Epoch 35/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0673 - accuracy: 0.9789 - auc: 0.9978
# Epoch 35: val_accuracy improved from 0.94460 to 0.94972, saving model to /gdrive/My Drive/chkpoint/
# 166/166 [==============================] - 161s 970ms/step - loss: 0.0673 - accuracy: 0.9789 - auc: 0.9978 - val_loss: 0.1715 - val_accuracy: 0.9497 - val_auc: 0.9878 - lr: 9.9934e-05
# Epoch 36/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0647 - accuracy: 0.9794 - auc: 0.9979
# Epoch 36: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 161s 967ms/step - loss: 0.0647 - accuracy: 0.9794 - auc: 0.9979 - val_loss: 0.2401 - val_accuracy: 0.9250 - val_auc: 0.9770 - lr: 9.9930e-05
# Epoch 37/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9817 - auc: 0.9979
# Epoch 37: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 965ms/step - loss: 0.0636 - accuracy: 0.9817 - auc: 0.9979 - val_loss: 0.5329 - val_accuracy: 0.8148 - val_auc: 0.9065 - lr: 9.9926e-05
# Epoch 38/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0625 - accuracy: 0.9806 - auc: 0.9980
# Epoch 38: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 162s 973ms/step - loss: 0.0625 - accuracy: 0.9806 - auc: 0.9980 - val_loss: 0.2516 - val_accuracy: 0.9276 - val_auc: 0.9742 - lr: 9.9922e-05
# Epoch 39/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0627 - accuracy: 0.9809 - auc: 0.9981
# Epoch 39: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 161s 969ms/step - loss: 0.0627 - accuracy: 0.9809 - auc: 0.9981 - val_loss: 0.3159 - val_accuracy: 0.9168 - val_auc: 0.9667 - lr: 9.9918e-05
# Epoch 40/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0580 - accuracy: 0.9815 - auc: 0.9984
# Epoch 40: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 960ms/step - loss: 0.0580 - accuracy: 0.9815 - auc: 0.9984 - val_loss: 0.2346 - val_accuracy: 0.9315 - val_auc: 0.9786 - lr: 9.9913e-05
# Epoch 41/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0536 - accuracy: 0.9841 - auc: 0.9986
# Epoch 41: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 965ms/step - loss: 0.0536 - accuracy: 0.9841 - auc: 0.9986 - val_loss: 0.2805 - val_accuracy: 0.9199 - val_auc: 0.9696 - lr: 9.9909e-05
# Epoch 42/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0600 - accuracy: 0.9830 - auc: 0.9981
# Epoch 42: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 966ms/step - loss: 0.0600 - accuracy: 0.9830 - auc: 0.9981 - val_loss: 0.2844 - val_accuracy: 0.9131 - val_auc: 0.9665 - lr: 9.9904e-05
# Epoch 43/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0506 - accuracy: 0.9849 - auc: 0.9988
# Epoch 43: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 965ms/step - loss: 0.0506 - accuracy: 0.9849 - auc: 0.9988 - val_loss: 0.5896 - val_accuracy: 0.8332 - val_auc: 0.9132 - lr: 9.9900e-05
# Epoch 44/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0537 - accuracy: 0.9846 - auc: 0.9985
# Epoch 44: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 159s 960ms/step - loss: 0.0537 - accuracy: 0.9846 - auc: 0.9985 - val_loss: 0.6716 - val_accuracy: 0.8017 - val_auc: 0.8922 - lr: 9.9895e-05
# Epoch 45/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0509 - accuracy: 0.9852 - auc: 0.9988
# Epoch 45: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 158s 951ms/step - loss: 0.0509 - accuracy: 0.9852 - auc: 0.9988 - val_loss: 0.1833 - val_accuracy: 0.9446 - val_auc: 0.9869 - lr: 9.9890e-05
# Epoch 46/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0525 - accuracy: 0.9846 - auc: 0.9988
# Epoch 46: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 162s 972ms/step - loss: 0.0525 - accuracy: 0.9846 - auc: 0.9988 - val_loss: 0.3712 - val_accuracy: 0.8972 - val_auc: 0.9593 - lr: 9.9885e-05
# Epoch 47/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0550 - accuracy: 0.9833 - auc: 0.9986
# Epoch 47: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 158s 949ms/step - loss: 0.0550 - accuracy: 0.9833 - auc: 0.9986 - val_loss: 0.3307 - val_accuracy: 0.8943 - val_auc: 0.8916 - lr: 9.9880e-05
# Epoch 48/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0458 - accuracy: 0.9880 - auc: 0.9989
# Epoch 48: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 156s 940ms/step - loss: 0.0458 - accuracy: 0.9880 - auc: 0.9989 - val_loss: 0.1889 - val_accuracy: 0.9474 - val_auc: 0.9786 - lr: 9.9875e-05
# Epoch 49/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0505 - accuracy: 0.9844 - auc: 0.9989
# Epoch 49: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 156s 939ms/step - loss: 0.0505 - accuracy: 0.9844 - auc: 0.9989 - val_loss: 0.2974 - val_accuracy: 0.9114 - val_auc: 0.9655 - lr: 9.9869e-05
# Epoch 50/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0420 - accuracy: 0.9876 - auc: 0.9992
# Epoch 50: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 157s 948ms/step - loss: 0.0420 - accuracy: 0.9876 - auc: 0.9992 - val_loss: 0.3464 - val_accuracy: 0.8980 - val_auc: 0.9589 - lr: 9.9864e-05
# Epoch 51/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0440 - accuracy: 0.9869 - auc: 0.9990
# Epoch 51: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 163s 982ms/step - loss: 0.0440 - accuracy: 0.9869 - auc: 0.9990 - val_loss: 0.4479 - val_accuracy: 0.8818 - val_auc: 0.9442 - lr: 9.9858e-05
# Epoch 52/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0446 - accuracy: 0.9873 - auc: 0.9990
# Epoch 52: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 162s 975ms/step - loss: 0.0446 - accuracy: 0.9873 - auc: 0.9990 - val_loss: 0.3667 - val_accuracy: 0.8946 - val_auc: 0.9598 - lr: 9.9853e-05
# Epoch 53/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0438 - accuracy: 0.9872 - auc: 0.9991
# Epoch 53: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 165s 996ms/step - loss: 0.0438 - accuracy: 0.9872 - auc: 0.9991 - val_loss: 0.1939 - val_accuracy: 0.9477 - val_auc: 0.9864 - lr: 9.9847e-05
# Epoch 54/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0434 - accuracy: 0.9869 - auc: 0.9992
# Epoch 54: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 159s 960ms/step - loss: 0.0434 - accuracy: 0.9869 - auc: 0.9992 - val_loss: 0.2162 - val_accuracy: 0.9429 - val_auc: 0.9823 - lr: 9.9841e-05
# Epoch 55/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0472 - accuracy: 0.9863 - auc: 0.9989
# Epoch 55: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 159s 955ms/step - loss: 0.0472 - accuracy: 0.9863 - auc: 0.9989 - val_loss: 0.4622 - val_accuracy: 0.8656 - val_auc: 0.9036 - lr: 9.9835e-05
# Epoch 56/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0449 - accuracy: 0.9872 - auc: 0.9990
# Epoch 56: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 159s 957ms/step - loss: 0.0449 - accuracy: 0.9872 - auc: 0.9990 - val_loss: 0.2915 - val_accuracy: 0.9193 - val_auc: 0.9694 - lr: 9.9829e-05
# Epoch 57/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0374 - accuracy: 0.9898 - auc: 0.9993
# Epoch 57: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 960ms/step - loss: 0.0374 - accuracy: 0.9898 - auc: 0.9993 - val_loss: 0.3988 - val_accuracy: 0.8858 - val_auc: 0.9524 - lr: 9.9823e-05
# Epoch 58/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0397 - accuracy: 0.9883 - auc: 0.9990
# Epoch 58: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 164s 987ms/step - loss: 0.0397 - accuracy: 0.9883 - auc: 0.9990 - val_loss: 0.2492 - val_accuracy: 0.9233 - val_auc: 0.9755 - lr: 9.9816e-05
# Epoch 59/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0405 - accuracy: 0.9893 - auc: 0.9988
# Epoch 59: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 164s 985ms/step - loss: 0.0405 - accuracy: 0.9893 - auc: 0.9988 - val_loss: 0.1778 - val_accuracy: 0.9472 - val_auc: 0.9859 - lr: 9.9810e-05
# Epoch 60/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0389 - accuracy: 0.9895 - auc: 0.9991
# Epoch 60: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 160s 960ms/step - loss: 0.0389 - accuracy: 0.9895 - auc: 0.9991 - val_loss: 0.3248 - val_accuracy: 0.8952 - val_auc: 0.9555 - lr: 9.9804e-05
# Epoch 61/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0480 - accuracy: 0.9868 - auc: 0.9989
# Epoch 61: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 163s 980ms/step - loss: 0.0480 - accuracy: 0.9868 - auc: 0.9989 - val_loss: 0.2105 - val_accuracy: 0.9330 - val_auc: 0.9015 - lr: 9.9797e-05
# Epoch 62/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0453 - accuracy: 0.9879 - auc: 0.9990
# Epoch 62: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 155s 935ms/step - loss: 0.0453 - accuracy: 0.9879 - auc: 0.9990 - val_loss: 0.3604 - val_accuracy: 0.8878 - val_auc: 0.9370 - lr: 9.9790e-05
# Epoch 63/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0448 - accuracy: 0.9886 - auc: 0.9985
# Epoch 63: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 159s 960ms/step - loss: 0.0448 - accuracy: 0.9886 - auc: 0.9985 - val_loss: 0.1617 - val_accuracy: 0.9491 - val_auc: 0.9887 - lr: 9.9783e-05
# Epoch 64/64
# 166/166 [==============================] - ETA: 0s - loss: 0.0416 - accuracy: 0.9905 - auc: 0.9992
# Epoch 64: val_accuracy did not improve from 0.94972
# 166/166 [==============================] - 157s 944ms/step - loss: 0.0416 - accuracy: 0.9905 - auc: 0.9992 - val_loss: 0.2369 - val_accuracy: 0.9375 - val_auc: 0.9776 - lr: 9.9776e-05

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()

# %%
from keras.models import load_model

model.save('/gdrive/My Drive/chkpoint/InceptionV3_Epo64.h5')

# %%
test_acc = model.evaluate_generator(test_generator, steps= 3561 // batch_size, verbose=1)
print('test acc:', test_acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: UserWarning: `Model.evaluate_generator` is deprecated and will be removed in a future version. Please use `Model.evaluate`, which supports generators.
#   """Entry point for launching an IPython kernel.
# 55/55 [==============================] - 14s 263ms/step - loss: 0.2203 - accuracy: 0.8727 - auc: 0.9793
# test acc: [0.22026188671588898, 0.8727272748947144, 0.9793389439582825]

# %%
y=np.concatenate([test_generator.next()[1] for i in range(test_generator.__len__())])
true_labels=np.argmax(y, axis=-1)

prediction= model.predict(test_generator, verbose=2)
prediction=np.argmax(prediction, axis=-1)
# Out:
# 3561/3561 - 88s - 88s/epoch - 25ms/step

# %%
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
            horizontalalignment="center",
            color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
from sklearn.metrics import confusion_matrix
import itertools
import matplotlib.pyplot as plt
cm = confusion_matrix(y_true=true_labels, y_pred=prediction)

# %%
cm_plot_labels = ['melanoma','not melanoma']

# %%
plot_confusion_matrix(cm=cm, classes=cm_plot_labels, title='Confusion Matrix')
from sklearn.metrics import accuracy_score
acc=accuracy_score(true_labels,prediction) 
print('Accuracy: %.3f' % acc)
from sklearn.metrics import precision_score
precision = precision_score(true_labels,prediction,labels=[1,2], average='micro')
print('Precision: %.3f' % precision)
from sklearn.metrics import recall_score
recall = recall_score(true_labels,prediction, average='binary')
print('Recall: %.3f' % recall)
from sklearn.metrics import f1_score
score = f1_score(true_labels,prediction, average='binary')
print('F-Measure: %.3f' % score)
# Out:
# Confusion matrix, without normalization
# [[1591  190]
#  [  50 1730]]
# Accuracy: 0.933
# Precision: 0.901
# Recall: 0.972
# F-Measure: 0.935
